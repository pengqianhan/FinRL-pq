# %% [markdown]
# # Stock NeurIPS2018 Part 2. Train
# This series is a reproduction of *the process in the paper Practical Deep Reinforcement Learning Approach for Stock Trading*.
#
# This is the second part of the NeurIPS2018 series, introducing how to use FinRL to make data into the gym form environment, and train DRL agents on it.
#
# Other demos can be found at the repo of [FinRL-Tutorials]((https://github.com/AI4Finance-Foundation/FinRL-Tutorials)).

# %% [markdown]
# # Part 1. Install Packages

# %%
## install finrl library
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %%
import pandas as pd
from stable_baselines3.common.logger import configure

from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.config import INDICATORS, TRAINED_MODEL_DIR, RESULTS_DIR
from finrl.main import check_and_make_directories
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv

check_and_make_directories([TRAINED_MODEL_DIR])

# %% [markdown]
# # Part 2. Build A Market Environment in OpenAI Gym-style

# %% [markdown]
# ![rl_diagram_transparent_bg.png](data:image/png;base64,...)

# %% [markdown]
# The core element in reinforcement learning are **agent** and **environment**. You can understand RL as the following process:
#
# The agent is active in a world, which is the environment. It observe its current condition as a **state**, and is allowed to do certain **actions**. After the agent execute an action, it will arrive at a new state. At the same time, the environment will have feedback to the agent called **reward**, a numerical signal that tells how good or bad the new state is. As the figure above, agent and environment will keep doing this interaction.
#
# The goal of agent is to get as much cumulative reward as possible. Reinforcement learning is the method that agent learns to improve its behavior and achieve that goal.

# %% [markdown]
# To achieve this in Python, we follow the OpenAI gym style to build the stock data into environment.
#
# state-action-reward are specified as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes the price data and technical indicators based on the past data. It will learn by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 constituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.

# %% [markdown]
# ## Read data
#
# We first read the .csv file of our training data into dataframe.

# %%
train = pd.read_csv('train_data.csv')
# print('before set index: \n',train.head(3))
# If you are not using the data generated from part 1 of this tutorial, make sure 
# it has the columns and index in the form that could be make into the environment. 
# Then you can comment and skip the following two lines.
train = train.set_index(train.columns[0])
train.index.names = ['']
# print('after set index: \n',train.head(3))

# %% [markdown]
# ## Construct the environment

# %% [markdown]
# Calculate and specify the parameters we need for constructing the environment.

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# # Part 3: Train DRL Agents
# * Here, the DRL algorithms are from **[Stable Baselines 3](https://stable-baselines3.readthedocs.io/en/master/)**. It's a library that implemented popular DRL algorithms using pytorch, succeeding to its old version: Stable Baselines.
# * Users are also encouraged to try **[ElegantRL](https://github.com/AI4Finance-Foundation/ElegantRL)** and **[Ray RLlib](https://github.com/ray-project/ray)**.

# %%
agent = DRLAgent(env = env_train)

# Set the corresponding values to 'True' for the algorithms that you want to use
if_using_a2c = True
if_using_ddpg = True
if_using_ppo = True
if_using_td3 = True
if_using_sac = True

# %% [markdown]
# ## Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device
# Logging to results/a2c

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000) if if_using_a2c else None
# Out:
# ---------------------------------------
# | time/                 |             |
# |    fps                | 193         |
# |    iterations         | 100         |
# |    time_elapsed       | 2           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | -0.0174     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -19.9       |
# |    reward             | 0.066304885 |
# |    reward_max         | 1.5811138   |
# |    reward_mean        | 0.20174348  |
# |    reward_min         | -0.40216115 |
# |    std                | 1           |
# |    value_loss         | 0.613       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 195        |
# |    iterations         | 200        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -0.0506    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -21.3      |
# |    reward             | 0.7142635  |
# |    reward_max         | 3.3176959  |
# |    reward_mean        | 1.5533344  |
# |    reward_min         | -1.7477328 |
# |    std                | 1          |
# |    value_loss         | 0.926      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 195        |
# |    iterations         | 300        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -127       |
# |    reward             | 4.8647847  |
# |    reward_max         | 4.8647847  |
# |    reward_mean        | -1.8040056 |
# |    reward_min         | -6.081437  |
# |    std                | 1          |
# |    value_loss         | 11.7       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 196        |
# |    iterations         | 400        |
# |    time_elapsed       | 10         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 231        |
# |    reward             | -3.0681198 |
# |    reward_max         | 6.9089828  |
# |    reward_mean        | 0.8957565  |
# |    reward_min         | -3.0681198 |
# |    std                | 1          |
# |    value_loss         | 31.7       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 197        |
# |    iterations         | 500        |
# |    time_elapsed       | 12         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 400        |
# |    reward             | -10.349068 |
# |    reward_max         | 6.5985107  |
# |    reward_mean        | -3.5545547 |
# |    reward_min         | -20.926483 |
# |    std                | 1.01       |
# |    value_loss         | 181        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 197        |
# |    iterations         | 600        |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -0.139     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | 180        |
# |    reward             | -0.1434213 |
# |    reward_max         | 1.1510005  |
# |    reward_mean        | 0.10227827 |
# |    reward_min         | -0.4929718 |
# |    std                | 1.01       |
# |    value_loss         | 20.2       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 197         |
# |    iterations         | 700         |
# |    time_elapsed       | 17          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | -39.3       |
# |    reward             | -3.2349377  |
# |    reward_max         | 1.0331621   |
# |    reward_mean        | -0.28347126 |
# |    reward_min         | -3.2349377  |
# |    std                | 1.01        |
# |    value_loss         | 1.47        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 198        |
# |    iterations         | 800        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 77.2       |
# |    reward             | -2.5145447 |
# |    reward_max         | 1.6624029  |
# |    reward_mean        | -0.7313407 |
# |    reward_min         | -2.5145447 |
# |    std                | 1.01       |
# |    value_loss         | 6.2        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 198        |
# |    iterations         | 900        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0.656      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 62.3       |
# |    reward             | -0.7910956 |
# |    reward_max         | 0.90617174 |
# |    reward_mean        | -0.2030415 |
# |    reward_min         | -0.7929839 |
# |    std                | 1.01       |
# |    value_loss         | 2.76       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 198         |
# |    iterations         | 1000        |
# |    time_elapsed       | 25          |
# |    total_timesteps    | 5000        |
# | train/                |             |
# |    entropy_loss       | -41.5       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 999         |
# |    policy_loss        | 11.1        |
# |    reward             | -2.554257   |
# |    reward_max         | 2.5390384   |
# |    reward_mean        | -0.14122194 |
# |    reward_min         | -2.554257   |
# |    std                | 1.01        |
# |    value_loss         | 0.318       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 198        |
# |    iterations         | 1100       |
# |    time_elapsed       | 27         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | -307       |
# |    reward             | 3.1098874  |
# |    reward_max         | 4.02594    |
# |    reward_mean        | -1.1671005 |
# |    reward_min         | -9.774979  |
# |    std                | 1.01       |
# |    value_loss         | 62.6       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 198         |
# |    iterations         | 1200        |
# |    time_elapsed       | 30          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1199        |
# |    policy_loss        | -111        |
# |    reward             | 0.051048044 |
# |    reward_max         | 3.2379553   |
# |    reward_mean        | 1.1569585   |
# |    reward_min         | 0.051048044 |
# |    std                | 1.01        |
# |    value_loss         | 8.82        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 198        |
# |    iterations         | 1300       |
# |    time_elapsed       | 32         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 120        |
# |    reward             | -5.01245   |
# |    reward_max         | 7.0460243  |
# |    reward_mean        | 0.24995878 |
# |    reward_min         | -5.01245   |
# |    std                | 1.01       |
# |    value_loss         | 21.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 199        |
# |    iterations         | 1400       |
# |    time_elapsed       | 35         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0.463      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 116        |
# |    reward             | 0.11842116 |
# |    reward_max         | 1.0553498  |
# |    reward_mean        | -1.4027063 |
# |    reward_min         | -7.522028  |
# |    std                | 1.01       |
# |    value_loss         | 9.59       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 199         |
# |    iterations         | 1500        |
# |    time_elapsed       | 37          |
# |    total_timesteps    | 7500        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | -2.38e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1499        |
# |    policy_loss        | -60.8       |
# |    reward             | 2.6017678   |
# |    reward_max         | 4.946537    |
# |    reward_mean        | 1.3579845   |
# |    reward_min         | -0.98281956 |
# |    std                | 1.01        |
# |    value_loss         | 4.11        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 199        |
# |    iterations         | 1600       |
# |    time_elapsed       | 40         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 221        |
# |    reward             | 1.3897935  |
# |    reward_max         | 2.045963   |
# |    reward_mean        | 0.8357441  |
# |    reward_min         | -1.2091955 |
# |    std                | 1.01       |
# |    value_loss         | 32.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 199        |
# |    iterations         | 1700       |
# |    time_elapsed       | 42         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | -178       |
# |    reward             | 4.811109   |
# |    reward_max         | 10.037037  |
# |    reward_mean        | 4.629704   |
# |    reward_min         | -1.1588963 |
# |    std                | 1.01       |
# |    value_loss         | 29.2       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 199         |
# |    iterations         | 1800        |
# |    time_elapsed       | 45          |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1799        |
# |    policy_loss        | -6.27       |
# |    reward             | 1.4003258   |
# |    reward_max         | 1.6125244   |
# |    reward_mean        | 0.73784703  |
# |    reward_min         | -0.41262543 |
# |    std                | 1           |
# |    value_loss         | 1.06        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 199         |
# |    iterations         | 1900        |
# |    time_elapsed       | 47          |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | -55.1       |
# |    reward             | -0.5203306  |
# |    reward_max         | 1.1945598   |
# |    reward_mean        | -0.18865326 |
# |    reward_min         | -1.4952517  |
# |    std                | 1           |
# |    value_loss         | 4.65        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 199        |
# |    iterations         | 2000       |
# |    time_elapsed       | 50         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 16.5       |
# |    reward             | 0.18885013 |
# |    reward_max         | 2.0632584  |
# |    reward_mean        | 1.5065608  |
# |    reward_min         | 0.18885013 |
# |    std                | 1          |
# |    value_loss         | 2.1        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 199        |
# |    iterations         | 2100       |
# |    time_elapsed       | 52         |
# |    total_timesteps    | 10500      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2099       |
# |    policy_loss        | 64.3       |
# |    reward             | 3.811923   |
# |    reward_max         | 3.811923   |
# |    reward_mean        | 0.73318046 |
# |    reward_min         | -2.4294531 |
# |    std                | 1          |
# |    value_loss         | 6.25       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 2200       |
# |    time_elapsed       | 54         |
# |    total_timesteps    | 11000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2199       |
# |    policy_loss        | -13.7      |
# |    reward             | -13.974984 |
# |    reward_max         | 2.7619774  |
# |    reward_mean        | -8.386829  |
# |    reward_min         | -21.616388 |
# |    std                | 1          |
# |    value_loss         | 25.8       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 200       |
# |    iterations         | 2300      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.0126    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | -1.75e+03 |
# |    reward             | 3.4219546 |
# |    reward_max         | 26.755156 |
# |    reward_mean        | 2.0425086 |
# |    reward_min         | -28.86233 |
# |    std                | 1         |
# |    value_loss         | 2.25e+03  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 2400       |
# |    time_elapsed       | 59         |
# |    total_timesteps    | 12000      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0.0144     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2399       |
# |    policy_loss        | 118        |
# |    reward             | 0.728172   |
# |    reward_max         | 2.8261585  |
# |    reward_mean        | 0.78721684 |
# |    reward_min         | -0.9525861 |
# |    std                | 1.01       |
# |    value_loss         | 18.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 2500       |
# |    time_elapsed       | 62         |
# |    total_timesteps    | 12500      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2499       |
# |    policy_loss        | -145       |
# |    reward             | 3.2812111  |
# |    reward_max         | 4.2107153  |
# |    reward_mean        | 1.1287202  |
# |    reward_min         | -3.4228065 |
# |    std                | 1          |
# |    value_loss         | 14.3       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 2600        |
# |    time_elapsed       | 64          |
# |    total_timesteps    | 13000       |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2599        |
# |    policy_loss        | 7.71        |
# |    reward             | 0.31401882  |
# |    reward_max         | 0.78295696  |
# |    reward_mean        | 0.04528095  |
# |    reward_min         | -0.79649794 |
# |    std                | 1           |
# |    value_loss         | 0.38        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 2700        |
# |    time_elapsed       | 67          |
# |    total_timesteps    | 13500       |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2699        |
# |    policy_loss        | 28.4        |
# |    reward             | -1.2503058  |
# |    reward_max         | 2.0505397   |
# |    reward_mean        | -0.16826572 |
# |    reward_min         | -1.407453   |
# |    std                | 1           |
# |    value_loss         | 1.44        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 2800       |
# |    time_elapsed       | 69         |
# |    total_timesteps    | 14000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -2.38e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2799       |
# |    policy_loss        | 475        |
# |    reward             | 5.2331414  |
# |    reward_max         | 5.2331414  |
# |    reward_mean        | 0.25956506 |
# |    reward_min         | -3.92274   |
# |    std                | 1          |
# |    value_loss         | 150        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 2900        |
# |    time_elapsed       | 72          |
# |    total_timesteps    | 14500       |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2899        |
# |    policy_loss        | -102        |
# |    reward             | 1.368166    |
# |    reward_max         | 1.368166    |
# |    reward_mean        | -0.22749414 |
# |    reward_min         | -1.2109092  |
# |    std                | 1           |
# |    value_loss         | 5.75        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 3000       |
# |    time_elapsed       | 74         |
# |    total_timesteps    | 15000      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2999       |
# |    policy_loss        | 64.9       |
# |    reward             | 1.0637108  |
# |    reward_max         | 3.569261   |
# |    reward_mean        | 0.3728438  |
# |    reward_min         | -2.1757123 |
# |    std                | 1.01       |
# |    value_loss         | 3.61       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 3100        |
# |    time_elapsed       | 77          |
# |    total_timesteps    | 15500       |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | -0.000197   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3099        |
# |    policy_loss        | 58.8        |
# |    reward             | -0.26834676 |
# |    reward_max         | 0.97979754  |
# |    reward_mean        | 0.10193719  |
# |    reward_min         | -1.070219   |
# |    std                | 1.01        |
# |    value_loss         | 2.8         |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 3200       |
# |    time_elapsed       | 79         |
# |    total_timesteps    | 16000      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3199       |
# |    policy_loss        | -74.1      |
# |    reward             | -1.5317323 |
# |    reward_max         | 5.1699085  |
# |    reward_mean        | 1.0485334  |
# |    reward_min         | -1.6597446 |
# |    std                | 1.01       |
# |    value_loss         | 23.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 3300       |
# |    time_elapsed       | 82         |
# |    total_timesteps    | 16500      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3299       |
# |    policy_loss        | 108        |
# |    reward             | 1.7049217  |
# |    reward_max         | 2.0785046  |
# |    reward_mean        | -0.634     |
# |    reward_min         | -3.1082692 |
# |    std                | 1.01       |
# |    value_loss         | 9.41       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 3400       |
# |    time_elapsed       | 84         |
# |    total_timesteps    | 17000      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3399       |
# |    policy_loss        | 75.1       |
# |    reward             | 8.029848   |
# |    reward_max         | 8.029848   |
# |    reward_mean        | 1.2850944  |
# |    reward_min         | -15.105746 |
# |    std                | 1.01       |
# |    value_loss         | 25.6       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 3500        |
# |    time_elapsed       | 87          |
# |    total_timesteps    | 17500       |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | -0.0207     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3499        |
# |    policy_loss        | 230         |
# |    reward             | -0.18218163 |
# |    reward_max         | 4.156399    |
# |    reward_mean        | 0.89737713  |
# |    reward_min         | -0.42633268 |
# |    std                | 1           |
# |    value_loss         | 39.5        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 3600       |
# |    time_elapsed       | 89         |
# |    total_timesteps    | 18000      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3599       |
# |    policy_loss        | -154       |
# |    reward             | 2.753041   |
# |    reward_max         | 3.1594946  |
# |    reward_mean        | 1.2601893  |
# |    reward_min         | -3.2823455 |
# |    std                | 1          |
# |    value_loss         | 23.7       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 3700        |
# |    time_elapsed       | 92          |
# |    total_timesteps    | 18500       |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3699        |
# |    policy_loss        | 234         |
# |    reward             | -0.30314896 |
# |    reward_max         | 2.9730678   |
# |    reward_mean        | 0.27071375  |
# |    reward_min         | -1.3213303  |
# |    std                | 1           |
# |    value_loss         | 40.8        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 200       |
# |    iterations         | 3800      |
# |    time_elapsed       | 94        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | 138       |
# |    reward             | 0.9029767 |
# |    reward_max         | 4.476511  |
# |    reward_mean        | 1.0539329 |
# |    reward_min         | -4.815145 |
# |    std                | 1         |
# |    value_loss         | 15.4      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 3900       |
# |    time_elapsed       | 97         |
# |    total_timesteps    | 19500      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3899       |
# |    policy_loss        | -170       |
# |    reward             | 2.9382102  |
# |    reward_max         | 2.9382102  |
# |    reward_mean        | 0.46735057 |
# |    reward_min         | -2.017644  |
# |    std                | 1.01       |
# |    value_loss         | 16.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 4000       |
# |    time_elapsed       | 99         |
# |    total_timesteps    | 20000      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3999       |
# |    policy_loss        | -429       |
# |    reward             | 5.3566256  |
# |    reward_max         | 5.8391743  |
# |    reward_mean        | 3.4256144  |
# |    reward_min         | 0.34075946 |
# |    std                | 1.01       |
# |    value_loss         | 116        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 4100        |
# |    time_elapsed       | 102         |
# |    total_timesteps    | 20500       |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4099        |
# |    policy_loss        | -52.4       |
# |    reward             | -0.25205788 |
# |    reward_max         | 0.93837404  |
# |    reward_mean        | 0.40811536  |
# |    reward_min         | -0.25205788 |
# |    std                | 1.01        |
# |    value_loss         | 5.73        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 4200       |
# |    time_elapsed       | 104        |
# |    total_timesteps    | 21000      |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4199       |
# |    policy_loss        | -111       |
# |    reward             | 2.8794956  |
# |    reward_max         | 5.353943   |
# |    reward_mean        | 2.2462254  |
# |    reward_min         | -1.2311405 |
# |    std                | 1.01       |
# |    value_loss         | 8.76       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 4300       |
# |    time_elapsed       | 107        |
# |    total_timesteps    | 21500      |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4299       |
# |    policy_loss        | -144       |
# |    reward             | 6.28516    |
# |    reward_max         | 6.28516    |
# |    reward_mean        | 0.21882075 |
# |    reward_min         | -3.2549145 |
# |    std                | 1.01       |
# |    value_loss         | 15.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 4400       |
# |    time_elapsed       | 109        |
# |    total_timesteps    | 22000      |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0.016      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4399       |
# |    policy_loss        | -7.09      |
# |    reward             | 4.585255   |
# |    reward_max         | 4.585255   |
# |    reward_mean        | -1.0374663 |
# |    reward_min         | -8.07161   |
# |    std                | 1.01       |
# |    value_loss         | 25.3       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 4500        |
# |    time_elapsed       | 112         |
# |    total_timesteps    | 22500       |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4499        |
# |    policy_loss        | 396         |
# |    reward             | -2.6010027  |
# |    reward_max         | 3.7441447   |
# |    reward_mean        | -0.80396616 |
# |    reward_min         | -6.422232   |
# |    std                | 1.01        |
# |    value_loss         | 108         |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 4600       |
# |    time_elapsed       | 114        |
# |    total_timesteps    | 23000      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4599       |
# |    policy_loss        | 538        |
# |    reward             | 4.7110853  |
# |    reward_max         | 4.7110853  |
# |    reward_mean        | 0.20257127 |
# |    reward_min         | -3.2144046 |
# |    std                | 1.01       |
# |    value_loss         | 177        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 4700       |
# |    time_elapsed       | 117        |
# |    total_timesteps    | 23500      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4699       |
# |    policy_loss        | -167       |
# |    reward             | 0.10442912 |
# |    reward_max         | 5.066043   |
# |    reward_mean        | 1.4443978  |
# |    reward_min         | -1.780807  |
# |    std                | 1.01       |
# |    value_loss         | 21.5       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 4800        |
# |    time_elapsed       | 119         |
# |    total_timesteps    | 24000       |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | -0.568      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4799        |
# |    policy_loss        | -160        |
# |    reward             | -0.6801698  |
# |    reward_max         | 1.0467504   |
# |    reward_mean        | 0.122268856 |
# |    reward_min         | -0.6801698  |
# |    std                | 1.01        |
# |    value_loss         | 17          |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 4900       |
# |    time_elapsed       | 122        |
# |    total_timesteps    | 24500      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4899       |
# |    policy_loss        | 6.98       |
# |    reward             | 1.2459875  |
# |    reward_max         | 2.9413645  |
# |    reward_mean        | 0.81957614 |
# |    reward_min         | -1.5060998 |
# |    std                | 1.01       |
# |    value_loss         | 0.471      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 5000        |
# |    time_elapsed       | 124         |
# |    total_timesteps    | 25000       |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4999        |
# |    policy_loss        | 15.1        |
# |    reward             | -1.0135834  |
# |    reward_max         | 2.6850371   |
# |    reward_mean        | -0.57417446 |
# |    reward_min         | -2.7052052  |
# |    std                | 1.01        |
# |    value_loss         | 3.04        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 200       |
# |    iterations         | 5100      |
# |    time_elapsed       | 127       |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | -148      |
# |    reward             | -2.17522  |
# |    reward_max         | 7.3775887 |
# |    reward_mean        | 1.7840843 |
# |    reward_min         | -3.272383 |
# |    std                | 1.01      |
# |    value_loss         | 32.2      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 200          |
# |    iterations         | 5200         |
# |    time_elapsed       | 129          |
# |    total_timesteps    | 26000        |
# | train/                |              |
# |    entropy_loss       | -41.3        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 5199         |
# |    policy_loss        | -570         |
# |    reward             | 6.544995     |
# |    reward_max         | 6.544995     |
# |    reward_mean        | -0.013512993 |
# |    reward_min         | -5.7801085   |
# |    std                | 1.01         |
# |    value_loss         | 200          |
# ----------------------------------------
# day: 2892, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 4812956.99
# total_reward: 3812956.99
# total_cost: 48626.45
# total_trades: 55064
# Sharpe: 0.918
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 5300        |
# |    time_elapsed       | 132         |
# |    total_timesteps    | 26500       |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5299        |
# |    policy_loss        | -56.6       |
# |    reward             | 0.55617285  |
# |    reward_max         | 0.7651112   |
# |    reward_mean        | 0.4815961   |
# |    reward_min         | 0.048258737 |
# |    std                | 1.01        |
# |    value_loss         | 1.99        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 5400       |
# |    time_elapsed       | 134        |
# |    total_timesteps    | 27000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5399       |
# |    policy_loss        | 88.5       |
# |    reward             | -0.42289   |
# |    reward_max         | 0.8724928  |
# |    reward_mean        | -0.8031587 |
# |    reward_min         | -3.5905154 |
# |    std                | 1          |
# |    value_loss         | 18.5       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 200       |
# |    iterations         | 5500      |
# |    time_elapsed       | 137       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | -73.5     |
# |    reward             | 2.7609258 |
# |    reward_max         | 4.05174   |
# |    reward_mean        | 2.7409647 |
# |    reward_min         | 1.2300113 |
# |    std                | 1         |
# |    value_loss         | 34.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 5600       |
# |    time_elapsed       | 139        |
# |    total_timesteps    | 28000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5599       |
# |    policy_loss        | -131       |
# |    reward             | -1.363195  |
# |    reward_max         | 1.4907643  |
# |    reward_mean        | -1.2535284 |
# |    reward_min         | -5.6479907 |
# |    std                | 1          |
# |    value_loss         | 13.6       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 5700        |
# |    time_elapsed       | 142         |
# |    total_timesteps    | 28500       |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5699        |
# |    policy_loss        | -35.8       |
# |    reward             | -0.78384334 |
# |    reward_max         | 3.885099    |
# |    reward_mean        | -3.5206325  |
# |    reward_min         | -11.9552355 |
# |    std                | 1           |
# |    value_loss         | 2.1         |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 5800       |
# |    time_elapsed       | 144        |
# |    total_timesteps    | 29000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5799       |
# |    policy_loss        | -10.7      |
# |    reward             | 2.1028206  |
# |    reward_max         | 4.9253845  |
# |    reward_mean        | 0.83052415 |
# |    reward_min         | -4.766465  |
# |    std                | 1          |
# |    value_loss         | 4.61       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 5900        |
# |    time_elapsed       | 147         |
# |    total_timesteps    | 29500       |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5899        |
# |    policy_loss        | 36.1        |
# |    reward             | 0.16300845  |
# |    reward_max         | 0.93566304  |
# |    reward_mean        | 0.21572937  |
# |    reward_min         | -0.70190006 |
# |    std                | 1           |
# |    value_loss         | 1.28        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 6000        |
# |    time_elapsed       | 149         |
# |    total_timesteps    | 30000       |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5999        |
# |    policy_loss        | 96.2        |
# |    reward             | -0.32898128 |
# |    reward_max         | 2.1565938   |
# |    reward_mean        | 0.301656    |
# |    reward_min         | -2.017494   |
# |    std                | 1.01        |
# |    value_loss         | 8.72        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 6100       |
# |    time_elapsed       | 152        |
# |    total_timesteps    | 30500      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6099       |
# |    policy_loss        | 27.9       |
# |    reward             | -3.3284206 |
# |    reward_max         | 3.9327857  |
# |    reward_mean        | -1.0140071 |
# |    reward_min         | -4.8726573 |
# |    std                | 1.01       |
# |    value_loss         | 7.93       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 6200        |
# |    time_elapsed       | 154         |
# |    total_timesteps    | 31000       |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6199        |
# |    policy_loss        | -2.16       |
# |    reward             | -0.96205705 |
# |    reward_max         | -0.16265331 |
# |    reward_mean        | -1.2844905  |
# |    reward_min         | -2.112347   |
# |    std                | 1.01        |
# |    value_loss         | 3.38        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 200       |
# |    iterations         | 6300      |
# |    time_elapsed       | 157       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -0.00168  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | 109       |
# |    reward             | 4.6669765 |
# |    reward_max         | 4.6669765 |
# |    reward_mean        | 1.1855394 |
# |    reward_min         | -2.983807 |
# |    std                | 1.01      |
# |    value_loss         | 17.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 6400       |
# |    time_elapsed       | 159        |
# |    total_timesteps    | 32000      |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0.0411     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6399       |
# |    policy_loss        | 138        |
# |    reward             | 1.0852052  |
# |    reward_max         | 1.9211811  |
# |    reward_mean        | 1.0966213  |
# |    reward_min         | 0.15396033 |
# |    std                | 1.01       |
# |    value_loss         | 14.3       |
# --------------------------------------
# ...
# |    reward_max         | 6.3963327  |
# |    reward_mean        | 1.341983   |
# |    reward_min         | -1.6658355 |
# |    std                | 1.02       |
# |    value_loss         | 185        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 8000       |
# |    time_elapsed       | 199        |
# |    total_timesteps    | 40000      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0.003      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7999       |
# |    policy_loss        | -201       |
# |    reward             | -1.4345688 |
# |    reward_max         | 5.1286716  |
# |    reward_mean        | 0.14789602 |
# |    reward_min         | -5.7837176 |
# |    std                | 1.02       |
# |    value_loss         | 42.2       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 8100       |
# |    time_elapsed       | 201        |
# |    total_timesteps    | 40500      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8099       |
# |    policy_loss        | 114        |
# |    reward             | 12.251088  |
# |    reward_max         | 12.251088  |
# |    reward_mean        | -1.0609767 |
# |    reward_min         | -17.610573 |
# |    std                | 1.02       |
# |    value_loss         | 40         |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 200          |
# |    iterations         | 8200         |
# |    time_elapsed       | 204          |
# |    total_timesteps    | 41000        |
# | train/                |              |
# |    entropy_loss       | -41.6        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 8199         |
# |    policy_loss        | 56.8         |
# |    reward             | -0.47081327  |
# |    reward_max         | 1.0214069    |
# |    reward_mean        | -0.004751989 |
# |    reward_min         | -0.87530905  |
# |    std                | 1.02         |
# |    value_loss         | 2.86         |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 8300        |
# |    time_elapsed       | 206         |
# |    total_timesteps    | 41500       |
# | train/                |             |
# |    entropy_loss       | -41.6       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8299        |
# |    policy_loss        | 41.2        |
# |    reward             | -2.9435608  |
# |    reward_max         | 2.4529004   |
# |    reward_mean        | -0.33535022 |
# |    reward_min         | -2.9435608  |
# |    std                | 1.02        |
# |    value_loss         | 1.97        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 8400       |
# |    time_elapsed       | 209        |
# |    total_timesteps    | 42000      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8399       |
# |    policy_loss        | 82.1       |
# |    reward             | -1.8593699 |
# |    reward_max         | 0.8490981  |
# |    reward_mean        | -2.9515955 |
# |    reward_min         | -6.429323  |
# |    std                | 1.02       |
# |    value_loss         | 6.68       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 8500       |
# |    time_elapsed       | 212        |
# |    total_timesteps    | 42500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8499       |
# |    policy_loss        | -2.94      |
# |    reward             | 0.87961036 |
# |    reward_max         | 6.1522427  |
# |    reward_mean        | 1.5752137  |
# |    reward_min         | -1.9207681 |
# |    std                | 1.02       |
# |    value_loss         | 2.25       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 8600       |
# |    time_elapsed       | 214        |
# |    total_timesteps    | 43000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8599       |
# |    policy_loss        | 98.2       |
# |    reward             | -15.781462 |
# |    reward_max         | 8.334206   |
# |    reward_mean        | -0.2563014 |
# |    reward_min         | -15.781462 |
# |    std                | 1.02       |
# |    value_loss         | 51.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 8700       |
# |    time_elapsed       | 217        |
# |    total_timesteps    | 43500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0.0225     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8699       |
# |    policy_loss        | -15.9      |
# |    reward             | 1.4335526  |
# |    reward_max         | 3.2977848  |
# |    reward_mean        | 1.3555913  |
# |    reward_min         | -0.6871667 |
# |    std                | 1.02       |
# |    value_loss         | 1.48       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 8800       |
# |    time_elapsed       | 219        |
# |    total_timesteps    | 44000      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8799       |
# |    policy_loss        | -90        |
# |    reward             | 1.0787759  |
# |    reward_max         | 1.1642778  |
# |    reward_mean        | -0.2802403 |
# |    reward_min         | -1.9092127 |
# |    std                | 1.02       |
# |    value_loss         | 5.49       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 8900       |
# |    time_elapsed       | 222        |
# |    total_timesteps    | 44500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8899       |
# |    policy_loss        | -39.9      |
# |    reward             | 0.3397502  |
# |    reward_max         | 0.3397502  |
# |    reward_mean        | -1.0204585 |
# |    reward_min         | -3.2220473 |
# |    std                | 1.02       |
# |    value_loss         | 2.38       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 9000       |
# |    time_elapsed       | 224        |
# |    total_timesteps    | 45000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8999       |
# |    policy_loss        | -20.4      |
# |    reward             | -0.7307926 |
# |    reward_max         | 3.7274394  |
# |    reward_mean        | 1.1268594  |
# |    reward_min         | -0.7307926 |
# |    std                | 1.02       |
# |    value_loss         | 6.05       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 9100        |
# |    time_elapsed       | 227         |
# |    total_timesteps    | 45500       |
# | train/                |             |
# |    entropy_loss       | -41.8       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9099        |
# |    policy_loss        | -30.1       |
# |    reward             | -0.5033903  |
# |    reward_max         | 0.058628738 |
# |    reward_mean        | -0.6389047  |
# |    reward_min         | -2.358253   |
# |    std                | 1.02        |
# |    value_loss         | 1.42        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 9200       |
# |    time_elapsed       | 229        |
# |    total_timesteps    | 46000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0.0363     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9199       |
# |    policy_loss        | -1.08      |
# |    reward             | 2.8491247  |
# |    reward_max         | 2.8491247  |
# |    reward_mean        | -1.3092395 |
# |    reward_min         | -8.123646  |
# |    std                | 1.02       |
# |    value_loss         | 1.85       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 9300       |
# |    time_elapsed       | 232        |
# |    total_timesteps    | 46500      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | -0.00163   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9299       |
# |    policy_loss        | -218       |
# |    reward             | 1.095195   |
# |    reward_max         | 3.6796038  |
# |    reward_mean        | 0.2375496  |
# |    reward_min         | -4.7717524 |
# |    std                | 1.02       |
# |    value_loss         | 29.6       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 9400        |
# |    time_elapsed       | 234         |
# |    total_timesteps    | 47000       |
# | train/                |             |
# |    entropy_loss       | -41.7       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9399        |
# |    policy_loss        | 340         |
# |    reward             | -0.23225766 |
# |    reward_max         | 7.540825    |
# |    reward_mean        | 1.0416733   |
# |    reward_min         | -6.530298   |
# |    std                | 1.02        |
# |    value_loss         | 73.3        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 9500        |
# |    time_elapsed       | 237         |
# |    total_timesteps    | 47500       |
# | train/                |             |
# |    entropy_loss       | -41.6       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9499        |
# |    policy_loss        | 121         |
# |    reward             | -0.16647667 |
# |    reward_max         | 2.7662287   |
# |    reward_mean        | 0.6869174   |
# |    reward_min         | -1.7462906  |
# |    std                | 1.02        |
# |    value_loss         | 10.6        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 9600       |
# |    time_elapsed       | 239        |
# |    total_timesteps    | 48000      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9599       |
# |    policy_loss        | -98.1      |
# |    reward             | 0.84110546 |
# |    reward_max         | 9.405118   |
# |    reward_mean        | 3.0079896  |
# |    reward_min         | 0.3650144  |
# |    std                | 1.02       |
# |    value_loss         | 10.2       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 9700       |
# |    time_elapsed       | 242        |
# |    total_timesteps    | 48500      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9699       |
# |    policy_loss        | 9.08       |
# |    reward             | 0.72004443 |
# |    reward_max         | 3.072634   |
# |    reward_mean        | 0.4401486  |
# |    reward_min         | -2.0359707 |
# |    std                | 1.02       |
# |    value_loss         | 2.45       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 9800        |
# |    time_elapsed       | 244         |
# |    total_timesteps    | 49000       |
# | train/                |             |
# |    entropy_loss       | -41.5       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9799        |
# |    policy_loss        | 280         |
# |    reward             | 6.115494    |
# |    reward_max         | 6.115494    |
# |    reward_mean        | -0.17484276 |
# |    reward_min         | -8.2667265  |
# |    std                | 1.01        |
# |    value_loss         | 59.6        |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 200          |
# |    iterations         | 9900         |
# |    time_elapsed       | 247          |
# |    total_timesteps    | 49500        |
# | train/                |              |
# |    entropy_loss       | -41.5        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 9899         |
# |    policy_loss        | -1.97        |
# |    reward             | -0.015909048 |
# |    reward_max         | 1.196017     |
# |    reward_mean        | -0.042749885 |
# |    reward_min         | -0.8895729   |
# |    std                | 1.01         |
# |    value_loss         | 0.195        |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 10000       |
# |    time_elapsed       | 249         |
# |    total_timesteps    | 50000       |
# | train/                |             |
# |    entropy_loss       | -41.5       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9999        |
# |    policy_loss        | 28.5        |
# |    reward             | -0.85326356 |
# |    reward_max         | 1.5722028   |
# |    reward_mean        | -0.04397886 |
# |    reward_min         | -1.3488064  |
# |    std                | 1.01        |
# |    value_loss         | 2.21        |
# ---------------------------------------

# %%
trained_a2c.save(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None

# %% [markdown]
# ### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device
# Logging to results/ddpg

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None
# Out:
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# ...
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'

# %%
trained_ddpg.save(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to results/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=200000) if if_using_ppo else None
# Out:
# -----------------------------------
# | time/              |            |
# |    fps             | 210        |
# |    iterations      | 1          |
# |    time_elapsed    | 9          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.5619844  |
# |    reward_max      | 8.420893   |
# |    reward_mean     | 0.09403824 |
# |    reward_min      | -8.957728  |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 2           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013414044 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00186     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.75        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0264     |
# |    reward               | 0.9500585   |
# |    reward_max           | 37.258953   |
# |    reward_mean          | 0.10393209  |
# |    reward_min           | -47.205368  |
# |    std                  | 1           |
# |    value_loss           | 13.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 3           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015352161 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00191     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 46.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0196     |
# |    reward               | -1.3079989  |
# |    reward_max           | 32.699585   |
# |    reward_mean          | 0.13246635  |
# |    reward_min           | -41.83155   |
# |    std                  | 1           |
# |    value_loss           | 73          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 4           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015271732 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.00229     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 40          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0204     |
# |    reward               | 3.2485445   |
# |    reward_max           | 9.105895    |
# |    reward_mean          | 0.12625763  |
# |    reward_min           | -16.688314  |
# |    std                  | 1           |
# |    value_loss           | 67.4        |
# -----------------------------------------
# day: 2892, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 3831489.22
# total_reward: 2831489.22
# total_cost: 319166.73
# total_trades: 80768
# Sharpe: 0.761
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 5           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020176966 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0186     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.47        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0178     |
# |    reward               | 3.121295    |
# |    reward_max           | 34.06822    |
# |    reward_mean          | 0.06662185  |
# |    reward_min           | -46.980026  |
# |    std                  | 1.01        |
# |    value_loss           | 20.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 6           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.025946736 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.00105    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 43.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0171     |
# |    reward               | 2.234022    |
# |    reward_max           | 28.93052    |
# |    reward_mean          | 0.0812382   |
# |    reward_min           | -37.365486  |
# |    std                  | 1.01        |
# |    value_loss           | 65.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 7           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.019142311 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.00333    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12          |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0162     |
# |    reward               | 2.657078    |
# |    reward_max           | 18.017462   |
# |    reward_mean          | 0.17110808  |
# |    reward_min           | -16.85527   |
# |    std                  | 1.01        |
# |    value_loss           | 52.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 8           |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.022227362 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.0125     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.7        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0172     |
# |    reward               | 0.22915547  |
# |    reward_max           | 39.371315   |
# |    reward_mean          | 0.04376671  |
# |    reward_min           | -48.48589   |
# |    std                  | 1.01        |
# |    value_loss           | 32.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 9           |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.020404138 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | -0.00956    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.6        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0193     |
# |    reward               | 0.97999847  |
# |    reward_max           | 31.661499   |
# |    reward_mean          | 0.09777585  |
# |    reward_min           | -40.60581   |
# |    std                  | 1.01        |
# |    value_loss           | 64.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 10          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.026285447 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | 0.00442     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.4        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0144     |
# |    reward               | 0.290486    |
# |    reward_max           | 38.198368   |
# |    reward_mean          | 0.12126063  |
# |    reward_min           | -48.34005   |
# |    std                  | 1.01        |
# |    value_loss           | 58          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 11          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.021982571 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | 0.00376     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 59.5        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0117     |
# |    reward               | -2.5649123  |
# |    reward_max           | 9.632929    |
# |    reward_mean          | 0.12902081  |
# |    reward_min           | -10.715057  |
# |    std                  | 1.01        |
# |    value_loss           | 96          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 12          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.027948111 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | 0.0212      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.83        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0194     |
# |    reward               | -0.1313205  |
# |    reward_max           | 38.82943    |
# |    reward_mean          | 0.07867862  |
# |    reward_min           | -53.799503  |
# |    std                  | 1.01        |
# |    value_loss           | 20.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 13          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.026715979 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | 0.0121      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 45.8        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.017      |
# |    reward               | 0.22070464  |
# |    reward_max           | 46.59301    |
# |    reward_mean          | 0.17370819  |
# |    reward_min           | -71.235466  |
# |    std                  | 1.01        |
# |    value_loss           | 91          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 14          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.024114903 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | 0.00463     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 57          |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0128     |
# |    reward               | -1.2312859  |
# |    reward_max           | 18.678167   |
# |    reward_mean          | 0.14726664  |
# |    reward_min           | -17.216442  |
# |    std                  | 1.02        |
# |    value_loss           | 120         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 15          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.020616898 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | 0.00846     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14          |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0174     |
# |    reward               | 4.721715    |
# |    reward_max           | 42.316414   |
# |    reward_mean          | 0.0643267   |
# |    reward_min           | -62.247524  |
# |    std                  | 1.02        |
# |    value_loss           | 32.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 16          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.018771924 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | -0.000751   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 32.1        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0149     |
# |    reward               | -0.29303828 |
# |    reward_max           | 34.492523   |
# |    reward_mean          | 0.13491495  |
# |    reward_min           | -49.952812  |
# |    std                  | 1.02        |
# |    value_loss           | 81.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 17          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.024107726 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | 0.00462     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 58.9        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0208     |
# |    reward               | 0.78139144  |
# |    reward_max           | 39.980473   |
# |    reward_mean          | 0.12844639  |
# |    reward_min           | -55.026783  |
# |    std                  | 1.02        |
# |    value_loss           | 73.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 18          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.017330954 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.00748     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 91          |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0141     |
# |    reward               | -0.77593    |
# |    reward_max           | 8.839511    |
# |    reward_mean          | 0.10037888  |
# |    reward_min           | -9.042777   |
# |    std                  | 1.02        |
# |    value_loss           | 102         |
# -----------------------------------------
# day: 2892, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 4596066.45
# total_reward: 3596066.45
# total_cost: 288333.62
# total_trades: 77596
# Sharpe: 0.810
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 19          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.030692559 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.0239      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.28        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0174     |
# |    reward               | 0.06459933  |
# |    reward_max           | 40.13294    |
# |    reward_mean          | 0.13088614  |
# |    reward_min           | -60.814423  |
# |    std                  | 1.02        |
# |    value_loss           | 15.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 205          |
# |    iterations           | 20           |
# |    time_elapsed         | 199          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.024819773  |
# |    clip_fraction        | 0.243        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.9        |
# |    explained_variance   | 0.0385       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 21.1         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0154      |
# |    reward               | -0.050234623 |
# |    reward_max           | 41.78831     |
# |    reward_mean          | 0.14918172   |
# |    reward_min           | -61.679977   |
# |    std                  | 1.03         |
# |    value_loss           | 78.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 21          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.019650199 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | 0.0363      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 90.5        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.018      |
# |    reward               | -5.4821167  |
# |    reward_max           | 12.174453   |
# |    reward_mean          | 0.10828551  |
# |    reward_min           | -19.680538  |
# |    std                  | 1.03        |
# |    value_loss           | 99.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 22          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.022975195 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | -0.00831    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 20.1        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0126     |
# |    reward               | 0.5870866   |
# |    reward_max           | 33.60587    |
# |    reward_mean          | 0.11424297  |
# |    reward_min           | -33.505405  |
# |    std                  | 1.03        |
# |    value_loss           | 39          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 23          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.026560277 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.02        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 16          |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0167     |
# |    reward               | -0.4324058  |
# |    reward_max           | 29.449047   |
# |    reward_mean          | 0.09143076  |
# |    reward_min           | -30.210907  |
# |    std                  | 1.03        |
# |    value_loss           | 45.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 24          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.022096828 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.0054      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 29.6        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0164     |
# |    reward               | 2.194984    |
# |    reward_max           | 25.90635    |
# |    reward_mean          | 0.09419748  |
# |    reward_min           | -26.739481  |
# |    std                  | 1.03        |
# |    value_loss           | 58.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 25          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.02585518  |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.00817     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22.1        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0101     |
# |    reward               | -0.74555284 |
# |    reward_max           | 11.185879   |
# |    reward_mean          | 0.11017806  |
# |    reward_min           | -14.43593   |
# |    std                  | 1.03        |
# |    value_loss           | 50.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 205        |
# |    iterations           | 26         |
# |    time_elapsed         | 259        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.02943796 |
# |    clip_fraction        | 0.281      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.1      |
# |    explained_variance   | 0.109      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 6.72       |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0157    |
# |    reward               | 1.6638993  |
# |    reward_max           | 43.13944   |
# |    reward_mean          | 0.13096379 |
# |    reward_min           | -58.295483 |
# |    std                  | 1.03       |
# |    value_loss           | 16         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 27          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.021721832 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.0415      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 36.7        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0124     |
# |    reward               | -0.28453708 |
# |    reward_max           | 31.182514   |
# |    reward_mean          | 0.12765998  |
# |    reward_min           | -36.840755  |
# |    std                  | 1.03        |
# |    value_loss           | 92.1        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 205        |
# |    iterations           | 28         |
# |    time_elapsed         | 278        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.03151901 |
# |    clip_fraction        | 0.278      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.2      |
# |    explained_variance   | -0.00377   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 29.5       |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.00788   |
# |    reward               | -3.5405793 |
# |    reward_max           | 13.626432  |
# |    reward_mean          | 0.17659895 |
# |    reward_min           | -22.10658  |
# |    std                  | 1.04       |
# |    value_loss           | 98         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 29          |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.025669694 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | -0.104      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 23.9        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00893    |
# |    reward               | -0.39328966 |
# |    reward_max           | 43.485943   |
# |    reward_mean          | 0.08786665  |
# |    reward_min           | -64.461174  |
# |    std                  | 1.04        |
# |    value_loss           | 39.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 205        |
# |    iterations           | 30         |
# |    time_elapsed         | 298        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.03003246 |
# |    clip_fraction        | 0.25       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.3      |
# |    explained_variance   | 0.000829   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 91.1       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0153    |
# |    reward               | 0.36910278 |
# |    reward_max           | 35.856594  |
# |    reward_mean          | 0.1379581  |
# |    reward_min           | -43.62497  |
# |    std                  | 1.04       |
# |    value_loss           | 120        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 31          |
# |    time_elapsed         | 308         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.020162914 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.3       |
# |    explained_variance   | 0.00499     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 57.4        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00747    |
# |    reward               | -0.86459684 |
# |    reward_max           | 17.476568   |
# |    reward_mean          | 0.1557175   |
# |    reward_min           | -22.248964  |
# |    std                  | 1.04        |
# |    value_loss           | 107         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 32          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.025019225 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | -0.00911    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 49.6        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00397    |
# |    reward               | -0.33315653 |
# |    reward_max           | 36.01978    |
# |    reward_mean          | 0.077665605 |
# |    reward_min           | -35.95995   |
# |    std                  | 1.04        |
# |    value_loss           | 69          |
# -----------------------------------------
# day: 2892, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 4530996.72
# total_reward: 3530996.72
# total_cost: 264430.60
# total_trades: 75628
# Sharpe: 0.781
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 33          |
# |    time_elapsed         | 328         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.022010244 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | 0.0126      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21.8        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0111     |
# |    reward               | 0.54333746  |
# |    reward_max           | 37.710194   |
# |    reward_mean          | 0.14873274  |
# |    reward_min           | -46.93411   |
# |    std                  | 1.04        |
# |    value_loss           | 50.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 34          |
# |    time_elapsed         | 339         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.018886369 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | -0.0022     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 60.4        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0092     |
# |    reward               | 0.91597277  |
# |    reward_max           | 37.39573    |
# |    reward_mean          | 0.15908471  |
# |    reward_min           | -34.389442  |
# |    std                  | 1.05        |
# |    value_loss           | 123         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 35          |
# |    time_elapsed         | 349         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.029129226 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | 0.000162    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 66.7        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00496    |
# |    reward               | -3.3221028  |
# |    reward_max           | 13.699908   |
# |    reward_mean          | 0.10066554  |
# |    reward_min           | -19.858002  |
# |    std                  | 1.05        |
# |    value_loss           | 92.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 36         |
# |    time_elapsed         | 1257       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.03207218 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.5      |
# |    explained_variance   | 0.0165     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 19.4       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0183    |
# |    reward               | -5.5616603 |
# |    reward_max           | 36.94439   |
# |    reward_mean          | 0.14239892 |
# |    reward_min           | -33.05319  |
# |    std                  | 1.05       |
# |    value_loss           | 42.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 37          |
# |    time_elapsed         | 1267        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.022794574 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.6       |
# |    explained_variance   | 0.00249     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 45.3        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00699    |
# |    reward               | -0.39480346 |
# |    reward_max           | 42.160656   |
# |    reward_mean          | 0.14352098  |
# |    reward_min           | -37.316525  |
# |    std                  | 1.05        |
# |    value_loss           | 73.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 60         |
# |    iterations           | 38         |
# |    time_elapsed         | 1277       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.03499586 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.6      |
# |    explained_variance   | 0.000424   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 67.7       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.002     |
# |    reward               | -7.440699  |
# |    reward_max           | 16.465384  |
# |    reward_mean          | 0.09481549 |
# |    reward_min           | -19.15917  |
# |    std                  | 1.06       |
# |    value_loss           | 143        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 39          |
# |    time_elapsed         | 1287        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.031434588 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.7       |
# |    explained_variance   | -0.00153    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 23.9        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0057     |
# |    reward               | -1.1310229  |
# |    reward_max           | 31.776085   |
# |    reward_mean          | 0.08125735  |
# |    reward_min           | -34.470837  |
# |    std                  | 1.06        |
# |    value_loss           | 40.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 40          |
# |    time_elapsed         | 1296        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.022498619 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | 0.0499      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 27          |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0155     |
# |    reward               | -0.6801652  |
# |    reward_max           | 28.499113   |
# |    reward_mean          | 0.094894774 |
# |    reward_min           | -33.87443   |
# |    std                  | 1.06        |
# |    value_loss           | 53.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 41         |
# |    time_elapsed         | 1306       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.02391232 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.8      |
# |    explained_variance   | -0.0234    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 27.6       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00854   |
# |    reward               | 0.48427692 |
# |    reward_max           | 42.53427   |
# |    reward_mean          | 0.16306679 |
# |    reward_min           | -64.23712  |
# |    std                  | 1.06       |
# |    value_loss           | 52         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 42          |
# |    time_elapsed         | 1316        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.021787105 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | 0.00668     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 84.1        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00807    |
# |    reward               | 1.3524916   |
# |    reward_max           | 11.486302   |
# |    reward_mean          | 0.07156465  |
# |    reward_min           | -15.880124  |
# |    std                  | 1.06        |
# |    value_loss           | 122         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 43          |
# |    time_elapsed         | 1325        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.022654507 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | -0.0163     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.8        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0167     |
# |    reward               | -1.2244319  |
# |    reward_max           | 30.756887   |
# |    reward_mean          | 0.12056599  |
# |    reward_min           | -27.965218  |
# |    std                  | 1.06        |
# |    value_loss           | 28.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 44          |
# |    time_elapsed         | 1335        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.032225832 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | 0.0106      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 36.4        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0106     |
# |    reward               | 0.024852006 |
# |    reward_max           | 32.669224   |
# |    reward_mean          | 0.107690185 |
# |    reward_min           | -28.524288  |
# |    std                  | 1.06        |
# |    value_loss           | 53.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 45          |
# |    time_elapsed         | 1345        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.029802293 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.9       |
# |    explained_variance   | 0.00102     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 27.3        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00342    |
# |    reward               | -1.5468941  |
# |    reward_max           | 10.070001   |
# |    reward_mean          | 0.10593893  |
# |    reward_min           | -15.489999  |
# |    std                  | 1.07        |
# |    value_loss           | 71          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 46          |
# |    time_elapsed         | 1355        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.032183066 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43         |
# |    explained_variance   | 0.0209      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.9        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00884    |
# |    reward               | -8.334918   |
# |    reward_max           | 34.625637   |
# |    reward_mean          | 0.110013366 |
# |    reward_min           | -38.85621   |
# |    std                  | 1.07        |
# |    value_loss           | 28.3        |
# -----------------------------------------
# day: 2892, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 4472942.41
# total_reward: 3472942.41
# total_cost: 247991.18
# total_trades: 75018
# Sharpe: 0.791
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 47          |
# |    time_elapsed         | 1365        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.024534646 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.1       |
# |    explained_variance   | 0.0159      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 34.4        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00845    |
# |    reward               | 1.9584264   |
# |    reward_max           | 37.40512    |
# |    reward_mean          | 0.120850496 |
# |    reward_min           | -33.359108  |
# |    std                  | 1.07        |
# |    value_loss           | 58.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 71         |
# |    iterations           | 48         |
# |    time_elapsed         | 1374       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.0278901  |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.1      |
# |    explained_variance   | 0.0129     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 39.6       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.00792   |
# |    reward               | 19.503977  |
# |    reward_max           | 36.850155  |
# |    reward_mean          | 0.12354252 |
# |    reward_min           | -31.463633 |
# |    std                  | 1.07       |
# |    value_loss           | 83.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 49          |
# |    time_elapsed         | 1384        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.013154125 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.1       |
# |    explained_variance   | 0.0174      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 39.5        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00655    |
# |    reward               | -1.3951551  |
# |    reward_max           | 13.786773   |
# |    reward_mean          | 0.114588834 |
# |    reward_min           | -19.609722  |
# |    std                  | 1.07        |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 50          |
# |    time_elapsed         | 1393        |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.038167387 |
# |    clip_fraction        | 0.309       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.2       |
# |    explained_variance   | 0.0428      |
# |    learning_rate        | 0.00025     |
# ...
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.000421   |
# |    reward               | 0.1403271   |
# |    reward_max           | 28.407337   |
# |    reward_mean          | 0.12752302  |
# |    reward_min           | -30.98497   |
# |    std                  | 1.13        |
# |    value_loss           | 124         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 55         |
# |    iterations           | 83         |
# |    time_elapsed         | 3054       |
# |    total_timesteps      | 169984     |
# | train/                  |            |
# |    approx_kl            | 0.04123478 |
# |    clip_fraction        | 0.337      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -44.6      |
# |    explained_variance   | 0.013      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 22.6       |
# |    n_updates            | 820        |
# |    policy_gradient_loss | 0.00692    |
# |    reward               | 0.67469686 |
# |    reward_max           | 15.375472  |
# |    reward_mean          | 0.12326851 |
# |    reward_min           | -22.921251 |
# |    std                  | 1.13       |
# |    value_loss           | 58         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 84          |
# |    time_elapsed         | 3064        |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.03533101  |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.7       |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 26.1        |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.00145    |
# |    reward               | -2.989966   |
# |    reward_max           | 37.336384   |
# |    reward_mean          | 0.121914595 |
# |    reward_min           | -33.11833   |
# |    std                  | 1.13        |
# |    value_loss           | 45.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 85          |
# |    time_elapsed         | 3074        |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.017029203 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.7       |
# |    explained_variance   | 0.0704      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 24.5        |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00794    |
# |    reward               | -0.32063875 |
# |    reward_max           | 41.79222    |
# |    reward_mean          | 0.1514278   |
# |    reward_min           | -35.01612   |
# |    std                  | 1.13        |
# |    value_loss           | 74.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 86          |
# |    time_elapsed         | 3084        |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.027908292 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.8       |
# |    explained_variance   | 0.0794      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 55.1        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | 0.00258     |
# |    reward               | -2.408225   |
# |    reward_max           | 17.92799    |
# |    reward_mean          | 0.11746476  |
# |    reward_min           | -22.215076  |
# |    std                  | 1.13        |
# |    value_loss           | 132         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 57         |
# |    iterations           | 87         |
# |    time_elapsed         | 3094       |
# |    total_timesteps      | 178176     |
# | train/                  |            |
# |    approx_kl            | 0.03940668 |
# |    clip_fraction        | 0.364      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -44.8      |
# |    explained_variance   | 0.0179     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 22.8       |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.0058    |
# |    reward               | 3.2788916  |
# |    reward_max           | 39.03114   |
# |    reward_mean          | 0.1360931  |
# |    reward_min           | -33.135384 |
# |    std                  | 1.14       |
# |    value_loss           | 52.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 88          |
# |    time_elapsed         | 3103        |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.015940495 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.9       |
# |    explained_variance   | 0.135       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 24.1        |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.00325    |
# |    reward               | -1.7000625  |
# |    reward_max           | 37.6889     |
# |    reward_mean          | 0.12990388  |
# |    reward_min           | -32.610508  |
# |    std                  | 1.14        |
# |    value_loss           | 72.4        |
# -----------------------------------------
# day: 2892, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 4685048.71
# total_reward: 3685048.71
# total_cost: 245496.83
# total_trades: 73023
# Sharpe: 0.805
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 89          |
# |    time_elapsed         | 3113        |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.017346032 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.9       |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 30.9        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.003      |
# |    reward               | -0.03370681 |
# |    reward_max           | 36.33191    |
# |    reward_mean          | 0.1529112   |
# |    reward_min           | -32.971977  |
# |    std                  | 1.14        |
# |    value_loss           | 93.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 90          |
# |    time_elapsed         | 3123        |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.012402041 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.9       |
# |    explained_variance   | 0.0389      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 45.7        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0069     |
# |    reward               | -0.9240627  |
# |    reward_max           | 12.571593   |
# |    reward_mean          | 0.1046336   |
# |    reward_min           | -11.775314  |
# |    std                  | 1.14        |
# |    value_loss           | 93.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 91          |
# |    time_elapsed         | 3133        |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.035231322 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.9       |
# |    explained_variance   | 0.0483      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.4        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00735    |
# |    reward               | -1.0646116  |
# |    reward_max           | 31.358446   |
# |    reward_mean          | 0.10074294  |
# |    reward_min           | -30.330372  |
# |    std                  | 1.14        |
# |    value_loss           | 24.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 92          |
# |    time_elapsed         | 3143        |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.02506461  |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45         |
# |    explained_variance   | 0.0488      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 31.3        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0112     |
# |    reward               | -0.98019725 |
# |    reward_max           | 36.61582    |
# |    reward_mean          | 0.11769871  |
# |    reward_min           | -30.931614  |
# |    std                  | 1.14        |
# |    value_loss           | 56.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 93          |
# |    time_elapsed         | 3152        |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.026621738 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45         |
# |    explained_variance   | 0.109       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 44          |
# |    n_updates            | 920         |
# |    policy_gradient_loss | 0.000987    |
# |    reward               | 2.0950756   |
# |    reward_max           | 15.680888   |
# |    reward_mean          | 0.13787493  |
# |    reward_min           | -24.292553  |
# |    std                  | 1.14        |
# |    value_loss           | 92.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 94          |
# |    time_elapsed         | 3162        |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.018960338 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45         |
# |    explained_variance   | 0.0303      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 33.3        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.00649    |
# |    reward               | 1.7864145   |
# |    reward_max           | 41.358036   |
# |    reward_mean          | 0.13605347  |
# |    reward_min           | -34.37091   |
# |    std                  | 1.14        |
# |    value_loss           | 68          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 95          |
# |    time_elapsed         | 3172        |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.04069176  |
# |    clip_fraction        | 0.309       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45         |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 36.5        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | 0.00362     |
# |    reward               | 0.18389021  |
# |    reward_max           | 32.073467   |
# |    reward_mean          | 0.085559264 |
# |    reward_min           | -38.47593   |
# |    std                  | 1.14        |
# |    value_loss           | 73.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 96          |
# |    time_elapsed         | 3182        |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.047890723 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.1       |
# |    explained_variance   | 0.0166      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 40          |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.00172    |
# |    reward               | 1.085334    |
# |    reward_max           | 12.0193205  |
# |    reward_mean          | 0.09427927  |
# |    reward_min           | -14.081479  |
# |    std                  | 1.15        |
# |    value_loss           | 72.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 97          |
# |    time_elapsed         | 3191        |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.023286391 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.1       |
# |    explained_variance   | 0.026       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.5        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0099     |
# |    reward               | 1.8062326   |
# |    reward_max           | 24.9247     |
# |    reward_mean          | 0.086687684 |
# |    reward_min           | -27.422504  |
# |    std                  | 1.15        |
# |    value_loss           | 22.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 98          |
# |    time_elapsed         | 3201        |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.025704816 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.2       |
# |    explained_variance   | 0.0833      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.8        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.012      |
# |    reward               | -0.46878934 |
# |    reward_max           | 27.070045   |
# |    reward_mean          | 0.08022267  |
# |    reward_min           | -33.548176  |
# |    std                  | 1.15        |
# |    value_loss           | 33.1        |
# -----------------------------------------

# %%
trained_ppo.save(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None

# %% [markdown]
# ### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to results/td3

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None
# Out:
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# ...
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'

# %%
trained_td3.save(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None

# %% [markdown]
# ### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to results/sac

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=70000) if if_using_sac else None
# Out:
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# ...
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'

# %%
trained_sac.save(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## Save the trained agent
# Trained agents should have already been saved in the "trained_models" drectory after you run the code blocks above.
#
# For Colab users, the zip files should be at "./trained_models" or "/content/trained_models".
#
# For users running on your local environment, the zip files should be at "./trained_models".
